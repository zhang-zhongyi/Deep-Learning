# %%
import numpy as np
import skimage
from skimage import data, io, filters, color, exposure
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = '/Users/zhongyizhang/Desktop/domestic-cat-726989_960_720.jpg'
cat = io.imread(filename)
plt.imshow(cat)

# %%
type(cat), cat.shape
# Out:
# (numpy.ndarray, (639, 960, 3))

# %%
print(cat.min(), cat.max(), cat.mean())
# Out:
# 0 255 127.36858752825596

# %%
print ("Value of pixel(201,201) for Cat", cat[201, 201])
# Out:
# Value of pixel(201,201) for Cat [126 104  93]
